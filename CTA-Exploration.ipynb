# %%
# !wget -O CTA_ridership_info.csv https://data.cityofchicago.org/api/views/5neh-572f/rows.csv?accessType=DOWNLOAD

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
rides = pd.read_csv('CTA_ridership_info.csv')
rides.head()
# Out:
#    station_id         stationname        date daytype  rides
# 0       40010  Austin-Forest Park  01/01/2001       U    290
# 1       40020         Harlem-Lake  01/01/2001       U    633
# 2       40030        Pulaski-Lake  01/01/2001       U    483
# 3       40040        Quincy/Wells  01/01/2001       U    374
# 4       40050               Davis  01/01/2001       U    804

# %%
rides.groupby('stationname')['rides'].mean().sort_values(ascending=False).head()
# Out:
# stationname
# Clark/Lake            13661.190402
# Lake/State            13299.597592
# Chicago/State         12944.953208
# 95th/Dan Ryan         10859.289046
# Belmont-North Main    10440.290384
# Name: rides, dtype: float64

# %%
rides[rides['daytype']=='W'].groupby('stationname')['rides'].std().sort_values(ascending=False).head()
# Out:
# stationname
# Lake/State                 4292.931370
# Washington/State           3890.640503
# Addison-North Main         3289.670003
# Clark/Lake                 2742.644346
# Fullerton                  2602.717176
# 95th/Dan Ryan              2456.187271
# Roosevelt                  2333.949163
# Garfield-South Elevated    2174.034339
# Madison/Wabash             2057.797311
# Monroe/State               2010.899261
# Jackson/State              1966.352460
# UIC-Halsted                1920.430355
# Grand/State                1854.332822
# O'Hare Airport             1826.578013
# Belmont-North Main         1771.999266
# Chicago/State              1761.977279
# Washington/Dearborn        1756.663279
# Sox-35th-Dan Ryan          1687.018941
# Randolph/Wabash            1508.996279
# Adams/Wabash               1501.927201
# State/Lake                 1461.403667
# Chicago/Franklin           1397.695487
# 79th                       1300.225938
# Diversey                   1287.939677
# Jackson/Dearborn           1256.422558
# Damen/Milwaukee            1246.193074
# Merchandise Mart           1206.768666
# Clinton-Lake               1172.728128
# Logan Square               1144.274121
# Harrison                   1103.418599
#                               ...
# Cicero-Cermak               265.308822
# Kedzie-Lake                 253.298070
# Linden                      247.141335
# Oak Park-Forest Park        245.394677
# Central-Lake                240.548059
# 47th-South Elevated         235.558576
# Jarvis                      225.233999
# East 63rd-Cottage Grove     222.264383
# Cicero-Forest Park          219.110713
# Indiana                     206.519703
# Conservatory                199.546979
# Ashland-Orange              198.727592
# Austin-Lake                 196.587059
# Oak Park-Lake               194.127902
# 43rd                        187.541908
# Harlem-Forest Park          179.331298
# Cicero-Lake                 175.603409
# California-Lake             173.918198
# Laramie                     156.280822
# 51st                        155.477506
# Foster                      150.588707
# Noyes                       147.996691
# Ridgeland                   145.732945
# Kostner                     113.953552
# King Drive                  112.678007
# Main                        108.423327
# Dempster                    104.778935
# Central-Evanston            101.780477
# South Boulevard              80.038416
# Homan                         5.891883
# Name: rides, dtype: float64

# %%
rides[rides['stationname']=='Homan']
# Out:
#        station_id stationname        date daytype  rides
# 25691       41580       Homan  07/01/2001       U      0
# 25834       41580       Homan  07/02/2001       W      0
# 25977       41580       Homan  07/03/2001       W      0
# 26120       41580       Homan  07/04/2001       U      0
# 26263       41580       Homan  07/05/2001       W      0
# 26406       41580       Homan  07/06/2001       W      0
# 26549       41580       Homan  07/07/2001       A      0
# 26692       41580       Homan  07/08/2001       U      0
# 26835       41580       Homan  07/09/2001       W      0
# 26978       41580       Homan  07/10/2001       W      0
# 27121       41580       Homan  07/11/2001       W      0
# 27264       41580       Homan  07/12/2001       W      0
# 27407       41580       Homan  07/13/2001       W      0
# 27550       41580       Homan  07/14/2001       A      0
# 27693       41580       Homan  07/15/2001       U      0
# 27836       41580       Homan  07/16/2001       W      0
# 27979       41580       Homan  07/17/2001       W      0
# 28122       41580       Homan  07/18/2001       W      0
# 28265       41580       Homan  07/19/2001       W      0
# 28408       41580       Homan  07/20/2001       W      0
# 28551       41580       Homan  07/21/2001       A      0
# 28694       41580       Homan  07/22/2001       U      0
# 28837       41580       Homan  07/23/2001       W      0
# 28980       41580       Homan  07/24/2001       W      0
# 29123       41580       Homan  07/25/2001       W      0
# 29266       41580       Homan  07/26/2001       W      0
# 29409       41580       Homan  07/27/2001       W      0
# 29552       41580       Homan  07/28/2001       A      0
# 29695       41580       Homan  07/29/2001       U      0
# 29838       41580       Homan  07/30/2001       W      0
# 29981       41580       Homan  07/31/2001       W     27

# %%
rides['date'] = pd.to_datetime(rides['date'])

# %%
rides_annual = rides.groupby([rides['stationname'],rides['date'].dt.year]).sum()

# %%
rides_2016 = rides[rides['date'].dt.year == 2016].groupby('stationname')['rides'].sum()
rides_2001 = rides[rides['date'].dt.year == 2001].groupby('stationname')['rides'].sum()
rides_delta = (rides_2016-rides_2001)/rides_2001

# %%
rides_delta.sort_values(ascending=False)
# Out:
# stationname
# Conservatory               2.860312
# Kedzie-Cermak              2.067121
# Central Park               2.048178
# Pulaski-Cermak             1.835424
# Damen-Cermak               1.495283
# Grand/Milwaukee            1.290409
# Western-Cermak             1.287597
# California-Cermak          1.258800
# Clinton-Lake               1.244929
# 18th                       1.227814
# Kostner                    0.910150
# Chicago/Milwaukee          0.845713
# Harrison                   0.798809
# Roosevelt                  0.769159
# California/Milwaukee       0.727882
# Western/Milwaukee          0.717736
# Cicero-Cermak              0.707792
# Sedgwick                   0.663519
# Library                    0.644327
# North/Clybourn             0.615387
# Ashland-Lake               0.609335
# Damen/Milwaukee            0.602900
# Clinton-Forest Park        0.600959
# Chicago/Franklin           0.599140
# Lake/State                 0.590030
# Randolph/Wabash            0.578265
# Logan Square               0.534433
# Garfield-South Elevated    0.531102
# LaSalle                    0.522235
# 54th/Cermak                0.504169
#                              ...
# Main                      -0.035980
# 35-Bronzeville-IIT        -0.042062
# Ridgeland                 -0.071954
# Jackson/State             -0.072376
# 79th                      -0.074579
# Cumberland                -0.083842
# South Boulevard           -0.110243
# Howard                    -0.111467
# LaSalle/Van Buren         -0.158101
# 51st                      -0.165695
# Halsted/63rd              -0.167990
# Central-Lake              -0.168899
# 63rd-Dan Ryan             -0.171673
# Linden                    -0.177303
# Central-Evanston          -0.177867
# King Drive                -0.183358
# East 63rd-Cottage Grove   -0.212724
# Garfield-Dan Ryan         -0.231622
# 87th                      -0.234954
# 69th                      -0.249797
# 95th/Dan Ryan             -0.260790
# Ashland/63rd              -0.352982
# Madison/Wabash            -0.999870
# Cermak-McCormick Place          NaN
# Dempster-Skokie                 NaN
# Homan                           NaN
# Morgan-Lake                     NaN
# Oakton-Skokie                   NaN
# Skokie                          NaN
# Washington/State                NaN
# Name: rides, dtype: float64

# %%
rides_2001[40830]
# Out:
# 256183

# %%
(rides_2016.sum()-rides_2001.sum())/rides_2001.sum()
# Out:
# 0.19650139618884474

# %%
stops = pd.read_csv('CTA_-_System_Information_-_List_of__L__Stops.csv')

# %%
stops.head()
# Out:
#    STOP_ID DIRECTION_ID                        STOP_NAME  \
# 0    30162            W         18th (54th/Cermak-bound)
# 1    30161            E                18th (Loop-bound)
# 2    30022            N         35th/Archer (Loop-bound)
# 3    30023            S       35th/Archer (Midway-bound)
# 4    30214            S  35-Bronzeville-IIT (63rd-bound)
#
#            STATION_NAME           STATION_DESCRIPTIVE_NAME  MAP_ID   ADA  \
# 0                  18th                   18th (Pink Line)   40830  True
# 1                  18th                   18th (Pink Line)   40830  True
# 2           35th/Archer          35th/Archer (Orange Line)   40120  True
# 3           35th/Archer          35th/Archer (Orange Line)   40120  True
# 4  35th-Bronzeville-IIT  35th-Bronzeville-IIT (Green Line)   41120  True
#
#      RED   BLUE      G    BRN      P   Pexp      Y    Pnk      O  \
# 0  False  False  False  False  False  False  False   True  False
# 1  False  False  False  False  False  False  False   True  False
# 2  False  False  False  False  False  False  False  False   True
# 3  False  False  False  False  False  False  False  False   True
# 4  False  False   True  False  False  False  False  False  False
#
#                   Location
# 0  (41.857908, -87.669147)
# 1  (41.857908, -87.669147)
# 2  (41.829353, -87.680622)
# 3  (41.829353, -87.680622)
# 4  (41.831677, -87.625826)

# %%
rides_2016 = rides[rides['date'].dt.year == 2016].groupby('station_id')['rides'].sum()
rides_2001 = rides[rides['date'].dt.year == 2001].groupby('station_id')['rides'].sum()
rides_delta = (rides_2016-rides_2001)/rides_2001
stops['Delta_2016_2001'] = stops['MAP_ID'].apply(lambda x: rides_delta[x])
stops['Ridership_2016'] = stops['MAP_ID'].apply(lambda x: rides_2016[x])

# %%
stops['latitude'] = stops['Location'].apply(lambda x: x.strip('()').split(', ')[0])
stops['longitude'] = stops['Location'].apply(lambda x: x.strip('()').split(', ')[1])

# %%
stops
# Out:
#      STOP_ID DIRECTION_ID                                     STOP_NAME  \
# 0      30162            W                      18th (54th/Cermak-bound)
# 1      30161            E                             18th (Loop-bound)
# 2      30022            N                      35th/Archer (Loop-bound)
# 3      30023            S                    35th/Archer (Midway-bound)
# 4      30214            S               35-Bronzeville-IIT (63rd-bound)
# 5      30213            N             35-Bronzeville-IIT (Harlem-bound)
# 6      30246            S                             43rd (63rd-bound)
# 7      30245            N                           43rd (Harlem-bound)
# 8      30025            S                             51st (63rd-bound)
# 9      30024            N                           51st (Harlem-bound)
# 10     30113            E                      54th/Cermak (Loop-bound)
# 11     30114            W                54th/Cermak (Terminal arrival)
# 12     30192            S                             69th (95th-bound)
# 13     30191            N                           69th (Howard-bound)
# 14     30047            S                             79th (95th-bound)
# 15     30046            N                           79th (Howard-bound)
# 16     30089            S                    95th/Dan Ryan (95th-bound)
# 17     30088            N                  95th/Dan Ryan (Howard-bound)
# 18     30132            S                     Adams/Wabash (Inner Loop)
# 19     30131            N                     Adams/Wabash (Outer Loop)
# 20     30277            N                       Addison (Kimball-bound)
# 21     30278            S                          Addison (Loop-bound)
# 22     30274            S                          Addison (95th-bound)
# 23     30273            N                        Addison (Howard-bound)
# 24     30230            S                           Argyle (95th-bound)
# 25     30229            N                         Argyle (Howard-bound)
# 26     30275            N                           87th (Howard-bound)
# 27     30127            N               Armitage (Kimball-Linden-bound)
# 28     30128            S                         Armitage (Loop-bound)
# 29     30205            N                          Ashland (Loop-bound)
# ..       ...          ...                                           ...
# 270    30381            N         Cermak-McCormick Place (Harlem-bound)
# 271    30276            S                             87th (95th-bound)
# 272    30026            N                     Dempster-Skokie (Arrival)
# 273    30298            S                  Oakton-Skokie (Howard-bound)
# 274    30382            S           Cermak-McCormick Place (63rd-bound)
# 275    30210            S                             47th (63rd-bound)
# 276    30209            N                           47th (Harlem-bound)
# 277    30238            S                             47th (95th-bound)
# 278    30237            N                           47th (Howard-bound)
# 279    30175            N                 Howard (Linden, Skokie-bound)
# 280    30111            N                     California (O'Hare-bound)
# 281    30112            S                  California (Forest Pk-bound)
# 282    30271            N                        Chicago (O'Hare-bound)
# 283    30138            S                          Chicago (Loop-bound)
# 284    30137            N                Chicago (Kimball-Linden-bound)
# 285    30280            S                          Chicago (95th-bound)
# 286    30279            N                        Chicago (Howard-bound)
# 287    30272            S                     Chicago (Forest Pk-bound)
# 288    30178            S                             63rd (95th-bound)
# 289    30177            N                           63rd (Howard-bound)
# 290    30223            N                       Garfield (Howard-bound)
# 291    30190            W  Harlem (Forest Pk Branch) (Terminal arrival)
# 292    30165            E                     H.W. Library (Outer Loop)
# 293    30130            S     Western (O'Hare Branch) (Forest Pk-bound)
# 294    30289            N                           Lake (Howard-bound)
# 295    30270            S                        Roosevelt (95th-bound)
# 296    30171            N                     O'Hare (Terminal Arrival)
# 297    30042            E     Western (Forest Pk Branch) (O'Hare-bound)
# 298    30043            W  Western (Forest Pk Branch) (Forest Pk-bound)
# 299    30129            N        Western (O'Hare Branch) (O'Hare-bound)
#
#                                   STATION_NAME  \
# 0                                         18th
# 1                                         18th
# 2                                  35th/Archer
# 3                                  35th/Archer
# 4                         35th-Bronzeville-IIT
# 5                         35th-Bronzeville-IIT
# 6                                         43rd
# 7                                         43rd
# 8                                         51st
# 9                                         51st
# 10                                 54th/Cermak
# 11                                 54th/Cermak
# 12                                        69th
# 13                                        69th
# 14                                        79th
# 15                                        79th
# 16                               95th/Dan Ryan
# 17                               95th/Ran Ryan
# 18                                Adams/Wabash
# 19                                Adams/Wabash
# 20                                     Addison
# 21                                     Addison
# 22                                     Addison
# 23                                     Addison
# 24                                      Argyle
# 25                                      Argyle
# 26                                        87th
# 27                                    Armitage
# 28                                    Armitage
# 29                                     Ashland
# ..                                         ...
# 270                     Cermak-McCormick Place
# 271                                       87th
# 272                            Dempster-Skokie
# 273                              Oakton-Skokie
# 274                     Cermak-McCormick Place
# 275                                       47th
# 276                                       47th
# 277                                       47th
# 278                                       47th
# 279                                     Howard
# 280                                 California
# 281                                 California
# 282                                    Chicago
# 283                                    Chicago
# 284                                    Chicago
# 285                                    Chicago
# 286                                    Chicago
# 287                                    Chicago
# 288                                       63rd
# 289                                       63rd
# 290                                   Garfield
# 291                                     Harlem
# 292  Harold Washington Library-State/Van Buren
# 293                                    Western
# 294                                       Lake
# 295                                  Roosevelt
# 296                                     O'Hare
# 297                                    Western
# 298                                    Western
# 299                                    Western
#
#                               STATION_DESCRIPTIVE_NAME  MAP_ID    ADA    RED  \
# 0                                     18th (Pink Line)   40830   True  False
# 1                                     18th (Pink Line)   40830   True  False
# 2                            35th/Archer (Orange Line)   40120   True  False
# 3                            35th/Archer (Orange Line)   40120   True  False
# 4                    35th-Bronzeville-IIT (Green Line)   41120   True  False
# 5                    35th-Bronzeville-IIT (Green Line)   41120   True  False
# 6                                    43rd (Green Line)   41270   True  False
# 7                                    43rd (Green Line)   41270   True  False
# 8                                    51st (Green Line)   40130   True  False
# 9                                    51st (Green Line)   40130   True  False
# 10                             54th/Cermak (Pink Line)   40580   True  False
# 11                             54th/Cermak (Pink Line)   40580   True  False
# 12                                     69th (Red Line)   40990   True   True
# 13                                     69th (Red Line)   40990   True   True
# 14                                     79th (Red Line)   40240   True   True
# 15                                     79th (Red Line)   40240   True   True
# 16                            95th/Dan Ryan (Red Line)   40450   True   True
# 17                            95th/Ran Ryan (Red Line)   40450   True   True
# 18   Adams/Wabash (Brown, Green, Orange, Pink & Pur...   40680  False  False
# 19   Adams/Wabash (Brown, Green, Orange, Pink & Pur...   40680  False  False
# 20                                Addison (Brown Line)   41440   True  False
# 21                                Addison (Brown Line)   41440   True  False
# 22                                  Addison (Red Line)   41420   True   True
# 23                                  Addison (Red Line)   41420   True   True
# 24                                   Argyle (Red Line)   41200  False   True
# 25                                   Argyle (Red Line)   41200  False   True
# 26                                     87th (Red Line)   41430   True   True
# 27                     Armitage (Brown & Purple Lines)   40660   True  False
# 28                     Armitage (Brown & Purple Lines)   40660   True  False
# 29                               Ashland (Orange Line)   41060   True  False
# ..                                                 ...     ...    ...    ...
# 270                Cermak-McCormick Place (Green Line)   41690   True    NaN
# 271                                    87th (Red Line)   41430   True   True
# 272                     Dempster-Skokie  (Yellow Line)   40140   True  False
# 273                        Oakton-Skokie (Yellow Line)   41680   True  False
# 274                Cermak-McCormick Place (Green Line)   41690   True    NaN
# 275                                  47th (Green Line)   41080   True  False
# 276                                  47th (Green Line)   41080   True  False
# 277                                    47th (Red Line)   41230   True   True
# 278                                    47th (Red Line)   41230   True   True
# 279                Howard (Red, Purple & Yellow Lines)   40900   True  False
# 280                             California (Blue Line)   40570  False  False
# 281                            California  (Blue Line)   40570  False  False
# 282                                Chicago (Blue Line)   41410  False  False
# 283                     Chicago (Brown & Purple Lines)   40710   True  False
# 284                     Chicago (Brown & Purple Lines)   40710   True  False
# 285                                 Chicago (Red Line)   41450   True   True
# 286                                 Chicago (Red Line)   41450   True   True
# 287                                Chicago (Blue Line)   41410  False  False
# 288                                    63rd (Red Line)   40910   True   True
# 289                                    63rd (Red Line)   40910   True   True
# 290                                Garfield (Red Line)   41170   True   True
# 291            Harlem (Blue Line - Forest Park Branch)   40980  False  False
# 292  Harold Washington Library-State/Van Buren (Bro...   40850   True  False
# 293                Western (Blue Line - O'Hare Branch)   40670   True  False
# 294                                    Lake (Red Line)   41660   True   True
# 295              Roosevelt (Red, Orange & Green Lines)   41400   True   True
# 296                                 O'Hare (Blue Line)   40890   True  False
# 297           Western (Blue Line - Forest Park Branch)   40220  False  False
# 298           Western (Blue Line - Forest Park Branch)   40220  False  False
# 299                Western (Blue Line - O'Hare Branch)   40670   True  False
#
#       BLUE      G      ...           P   Pexp      Y    Pnk      O  \
# 0    False  False      ...       False  False  False   True  False
# 1    False  False      ...       False  False  False   True  False
# 2    False  False      ...       False  False  False  False   True
# 3    False  False      ...       False  False  False  False   True
# 4    False   True      ...       False  False  False  False  False
# 5    False   True      ...       False  False  False  False  False
# 6    False   True      ...       False  False  False  False  False
# 7    False   True      ...       False  False  False  False  False
# 8    False   True      ...       False  False  False  False  False
# 9    False   True      ...       False  False  False  False  False
# 10   False  False      ...       False  False  False   True  False
# 11   False  False      ...       False  False  False   True  False
# 12   False  False      ...       False  False  False  False  False
# 13   False  False      ...       False  False  False  False  False
# 14   False  False      ...       False  False  False  False  False
# 15   False  False      ...       False  False  False  False  False
# 16   False  False      ...       False  False  False  False  False
# 17   False  False      ...       False  False  False  False  False
# 18   False   True      ...       False   True  False   True   True
# 19   False   True      ...       False  False  False  False  False
# 20   False  False      ...       False  False  False  False  False
# 21   False  False      ...       False  False  False  False  False
# 22   False  False      ...       False  False  False  False  False
# 23   False  False      ...       False  False  False  False  False
# 24   False  False      ...       False  False  False  False  False
# 25   False  False      ...       False  False  False  False  False
# 26   False  False      ...       False  False  False  False  False
# 27   False  False      ...       False   True  False  False  False
# 28   False  False      ...       False   True  False  False  False
# 29   False  False      ...       False  False  False  False   True
# ..     ...    ...      ...         ...    ...    ...    ...    ...
# 270    NaN   True      ...         NaN    NaN    NaN    NaN    NaN
# 271  False  False      ...       False  False  False  False  False
# 272  False  False      ...       False  False   True  False  False
# 273  False  False      ...       False  False   True  False  False
# 274    NaN   True      ...         NaN    NaN    NaN    NaN    NaN
# 275  False   True      ...       False  False  False  False  False
# 276  False   True      ...       False  False  False  False  False
# 277  False  False      ...       False  False  False  False  False
# 278  False  False      ...       False  False  False  False  False
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-51-436794d52bdb> in <module>()
#      42 plot.add_tools(PanTool(), WheelZoomTool(), BoxZoomTool(), hover)
#      43 output_file('Change_in_ridership_map_2001_2016.html')
# ---> 44 show(plot)
#
# /home/ubuntu/anaconda2/envs/py3/lib/python3.5/site-packages/bokeh/io.py in show(obj, browser, new, notebook_handle, notebook_url)
#     282     if obj not in _state.document.roots:
#     283         _state.document.add_root(obj)
# --> 284     return _show_with_state(obj, _state, browser, new, notebook_handle=notebook_handle)
#     285
#     286
#
# /home/ubuntu/anaconda2/envs/py3/lib/python3.5/site-packages/bokeh/io.py in _show_with_state(obj, state, browser, new, notebook_handle)
#     312
#     313     if state.file or not shown:
# --> 314         _show_file_with_state(obj, state, new, controller)
#     315
#     316     return comms_handle
#
# /home/ubuntu/anaconda2/envs/py3/lib/python3.5/site-packages/bokeh/io.py in _show_file_with_state(obj, state, new, controller)
#     318 def _show_file_with_state(obj, state, new, controller):
#     319     filename = save(obj, state=state)
# --> 320     controller.open("file://" + filename, new=_new_param[new])
#     321
#     322 def _show_notebook_with_state(obj, state, notebook_handle):
#
# /home/ubuntu/anaconda2/envs/py3/lib/python3.5/webbrowser.py in open(url, new, autoraise)
#      58     for name in _tryorder:
#      59         browser = get(name)
# ---> 60         if browser.open(url, new, autoraise):
#      61             return True
#      62     return False
#
# /home/ubuntu/anaconda2/envs/py3/lib/python3.5/webbrowser.py in open(self, url, new, autoraise)
#     144             else:
#     145                 p = subprocess.Popen(cmdline, close_fds=True)
# --> 146             return not p.wait()
#     147         except OSError:
#     148             return False
#
# /home/ubuntu/anaconda2/envs/py3/lib/python3.5/subprocess.py in wait(self, timeout, endtime)
#    1656                         if self.returncode is not None:
#    1657                             break  # Another thread waited.
# -> 1658                         (pid, sts) = self._try_wait(0)
#    1659                         # Check the pid and loop as waitpid has been known to
#    1660                         # return 0 even without WNOHANG in odd situations.
#
# /home/ubuntu/anaconda2/envs/py3/lib/python3.5/subprocess.py in _try_wait(self, wait_flags)
#    1606             """All callers to this function MUST hold self._waitpid_lock."""
#    1607             try:
# -> 1608                 (pid, sts) = os.waitpid(self.pid, wait_flags)
#    1609             except ChildProcessError:
#    1610                 # This happens if SIGCLD is set to be ignored or waiting
#
# KeyboardInterrupt:

# %% [markdown]
# [map](Change_in_ridership_map_2001_2016.html)

# %%
rides_2011 = rides[rides['date'].dt.year == 2011].groupby('station_id')['rides'].sum()
rides_delta = (rides_2016-rides_2011)/rides_2011
stops['Delta_2016_2011'] = stops['MAP_ID'].apply(lambda x: rides_delta[x]*100)
stops['Ridership_2016'] = stops['MAP_ID'].apply(lambda x: rides_2016[x])


map_options = GMapOptions(lat=41.857908, lng=-87.669147, map_type="roadmap", zoom=11)

plot = GMapPlot(
    x_range=DataRange1d(), y_range=DataRange1d(), map_options=map_options, sizing_mode = 'scale_both'
)
plot.title.text = "CTA Change in Ridership 2011-2016"
plot.api_key = "AIzaSyAziAH5D6C2_kYB2HzELYm122SkME6uyX8"

hover = HoverTool(
        tooltips=[
            ("Stop", "@STATION_NAME"),
            ("Change from 2011 to 2016 (%)", "@Delta_2016_2011{0.00}"),
            ("Ridership (2016)", "@Ridership_2016"),
        ]
    )


#create size column with relative values
MIN_SIZE = 8
MAX_SIZE = 20
stops['size'] = ( (stops['Ridership_2016']-stops['Ridership_2016'].min()) /
                (stops['Ridership_2016'].max() - stops['Ridership_2016'].min())*MAX_SIZE ) + MIN_SIZE

#Scale ridership changes relative to total system wide changes
total_change = (rides_2016.sum()-rides_2011.sum())/rides_2011.sum()
stops['Delta_Rel_2016_2011'] = stops['Delta_2016_2011']-total_change*100

source = ColumnDataSource(data = stops.groupby('MAP_ID').first())

mapper = LinearColorMapper(palette=bokeh.palettes.RdYlGn[11], 
                           low=stops['Delta_Rel_2016_2011'].quantile(0.9), high=stops['Delta_Rel_2016_2011'].quantile(0.1))

circle = Circle(x="longitude", y="latitude", size='size',
                fill_color={'field': 'Delta_Rel_2016_2011', 'transform': mapper})
plot.add_glyph(source, circle)

plot.add_tools(PanTool(), WheelZoomTool(), BoxZoomTool(), hover)
output_file('Change_in_ridership_map_2011_2016.html')
show(plot)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-94-458641ad9119> in <module>()
#      43 plot.add_tools(PanTool(), WheelZoomTool(), BoxZoomTool(), hover)
#      44 output_file('Change_in_ridership_map_2011_2016.html')
# ---> 45 show(plot)
#
# /home/ubuntu/anaconda2/envs/py3/lib/python3.5/site-packages/bokeh/io.py in show(obj, browser, new, notebook_handle, notebook_url)
#     282     if obj not in _state.document.roots:
#     283         _state.document.add_root(obj)
# --> 284     return _show_with_state(obj, _state, browser, new, notebook_handle=notebook_handle)
#     285
#     286
#
# /home/ubuntu/anaconda2/envs/py3/lib/python3.5/site-packages/bokeh/io.py in _show_with_state(obj, state, browser, new, notebook_handle)
#     312
#     313     if state.file or not shown:
# --> 314         _show_file_with_state(obj, state, new, controller)
#     315
#     316     return comms_handle
#
# /home/ubuntu/anaconda2/envs/py3/lib/python3.5/site-packages/bokeh/io.py in _show_file_with_state(obj, state, new, controller)
#     318 def _show_file_with_state(obj, state, new, controller):
#     319     filename = save(obj, state=state)
# --> 320     controller.open("file://" + filename, new=_new_param[new])
#     321
#     322 def _show_notebook_with_state(obj, state, notebook_handle):
#
# /home/ubuntu/anaconda2/envs/py3/lib/python3.5/webbrowser.py in open(url, new, autoraise)
#      58     for name in _tryorder:
#      59         browser = get(name)
# ---> 60         if browser.open(url, new, autoraise):
#      61             return True
#      62     return False
#
# /home/ubuntu/anaconda2/envs/py3/lib/python3.5/webbrowser.py in open(self, url, new, autoraise)
#     144             else:
#     145                 p = subprocess.Popen(cmdline, close_fds=True)
# --> 146             return not p.wait()
#     147         except OSError:
#     148             return False
#
# /home/ubuntu/anaconda2/envs/py3/lib/python3.5/subprocess.py in wait(self, timeout, endtime)
#    1656                         if self.returncode is not None:
#    1657                             break  # Another thread waited.
# -> 1658                         (pid, sts) = self._try_wait(0)
#    1659                         # Check the pid and loop as waitpid has been known to
#    1660                         # return 0 even without WNOHANG in odd situations.
#
# /home/ubuntu/anaconda2/envs/py3/lib/python3.5/subprocess.py in _try_wait(self, wait_flags)
#    1606             """All callers to this function MUST hold self._waitpid_lock."""
#    1607             try:
# -> 1608                 (pid, sts) = os.waitpid(self.pid, wait_flags)
#    1609             except ChildProcessError:
#    1610                 # This happens if SIGCLD is set to be ignored or waiting
#
# KeyboardInterrupt:

# %% [markdown]
# [map](Change_in_ridership_map_2011_2016.html)

# %%
r_2016 = rides[rides['date'].dt.year==2016]
weekday = r_2016[r_2016['daytype']=='W'].groupby('station_id')['rides'].mean()
weekend = r_2016[r_2016['daytype']!='W'].groupby('station_id')['rides'].mean()
saturday = r_2016[r_2016['daytype']=='A'].groupby('station_id')['rides'].mean()
sunday = r_2016[r_2016['daytype']=='U'].groupby('station_id')['rides'].mean()

# %%
-
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-56-07239c2e4c03> in <module>()
#      38 plot.add_tools(PanTool(), WheelZoomTool(), BoxZoomTool(), hover)
#      39 output_file('Change_in_ridership_map_2016_weekend_use.html')
# ---> 40 show(plot)
#
# /home/ubuntu/anaconda2/envs/py3/lib/python3.5/site-packages/bokeh/io.py in show(obj, browser, new, notebook_handle, notebook_url)
#     282     if obj not in _state.document.roots:
#     283         _state.document.add_root(obj)
# --> 284     return _show_with_state(obj, _state, browser, new, notebook_handle=notebook_handle)
#     285
#     286
#
# /home/ubuntu/anaconda2/envs/py3/lib/python3.5/site-packages/bokeh/io.py in _show_with_state(obj, state, browser, new, notebook_handle)
#     312
#     313     if state.file or not shown:
# --> 314         _show_file_with_state(obj, state, new, controller)
#     315
#     316     return comms_handle
#
# /home/ubuntu/anaconda2/envs/py3/lib/python3.5/site-packages/bokeh/io.py in _show_file_with_state(obj, state, new, controller)
#     318 def _show_file_with_state(obj, state, new, controller):
#     319     filename = save(obj, state=state)
# --> 320     controller.open("file://" + filename, new=_new_param[new])
#     321
#     322 def _show_notebook_with_state(obj, state, notebook_handle):
#
# /home/ubuntu/anaconda2/envs/py3/lib/python3.5/webbrowser.py in open(url, new, autoraise)
#      58     for name in _tryorder:
#      59         browser = get(name)
# ---> 60         if browser.open(url, new, autoraise):
#      61             return True
#      62     return False
#
# /home/ubuntu/anaconda2/envs/py3/lib/python3.5/webbrowser.py in open(self, url, new, autoraise)
#     144             else:
#     145                 p = subprocess.Popen(cmdline, close_fds=True)
# --> 146             return not p.wait()
#     147         except OSError:
#     148             return False
#
# /home/ubuntu/anaconda2/envs/py3/lib/python3.5/subprocess.py in wait(self, timeout, endtime)
#    1656                         if self.returncode is not None:
#    1657                             break  # Another thread waited.
# -> 1658                         (pid, sts) = self._try_wait(0)
#    1659                         # Check the pid and loop as waitpid has been known to
#    1660                         # return 0 even without WNOHANG in odd situations.
#
# /home/ubuntu/anaconda2/envs/py3/lib/python3.5/subprocess.py in _try_wait(self, wait_flags)
#    1606             """All callers to this function MUST hold self._waitpid_lock."""
#    1607             try:
# -> 1608                 (pid, sts) = os.waitpid(self.pid, wait_flags)
#    1609             except ChildProcessError:
#    1610                 # This happens if SIGCLD is set to be ignored or waiting
#
# KeyboardInterrupt:

# %% [markdown]
# [map](Change_in_ridership_map_2016_weekend_use.html)

# %%
stops.sort_values(by='weekend_use',ascending=False)
# Out:
#      STOP_ID DIRECTION_ID                                    STOP_NAME  \
# 175    30124            S                  Madison/Wabash (Inner Loop)
# 176    30123            N                  Madison/Wabash (Outer Loop)
# 57     30194            S                Cermak-Chinatown (95th-bound)
# 58     30193            N              Cermak-Chinatown (Howard-bound)
# 22     30274            S                         Addison (95th-bound)
# 23     30273            N                       Addison (Howard-bound)
# 109    30064            N                   Grand/State (Howard-bound)
# 108    30065            S                     Grand/State (95th-bound)
# 296    30171            N                    O'Hare (Terminal Arrival)
# 227    30172            S                     O'Hare (Forest Pk-bound)
# 162    30136            W                       Laramie (Harlem-bound)
# 161    30135            E                         Laramie (63rd-bound)
# 197    30125            N                North/Clybourn (Howard-bound)
# 196    30126            S                  North/Clybourn (95th-bound)
# 258    30269            N                     Roosevelt (Howard-bound)
# 228    30080            N                Roosevelt (Loop-Harlem-bound)
# 295    30270            S                       Roosevelt (95th-bound)
# 259    30081            S                Roosevelt (Midway-63rd-bound)
# 41     30256            S                         Belmont (95th-bound)
# 43     30257            N               Belmont (Kimball-Linden-bound)
# 44     30258            S                         Belmont (Loop-bound)
# 42     30255            N                       Belmont (Howard-bound)
# 269    30121            N                Clark/Division (Howard-bound)
# 67     30122            S                  Clark/Division (95th-bound)
# 90     30133            N                      Dempster (Linden-bound)
# 89     30134            S                 Dempster (Howard-Loop-bound)
# 286    30279            N                       Chicago (Howard-bound)
# 285    30280            S                         Chicago (95th-bound)
# 121    30285            N                      Harrison (Howard-bound)
# 120    30286            S                        Harrison (95th-bound)
# ..       ...          ...                                          ...
# 73     30084            E                       Clinton (O'Hare-bound)
# 72     30085            W                    Clinton (Forest Pk-bound)
# 200    30035            W                   Oak Park (Forest Pk-bound)
# 201    30034            E                      Oak Park (O'Hare-bound)
# 223    30119            E                       Ridgeland (63rd-bound)
# 224    30120            W                     Ridgeland (Harlem-bound)
# 284    30137            N               Chicago (Kimball-Linden-bound)
# 283    30138            S                         Chicago (Loop-bound)
# 248    30068            E                   UIC-Halsted (O'Hare-bound)
# 247    30069            W                UIC-Halsted (Forest Pk-bound)
# 130    30157            E     Illinois Medical District (O'Hare-bound)
# 129    30158            W  Illinois Medical District (Forest Pk-bound)
# 191    30154            S                     Monroe (Forest Pk-bound)
# 194    30153            N                        Monroe (O'Hare-bound)
# 74     30222            W           Clinton (Harlem-54th/Cermak-bound)
# 75     30221            E                    Clinton (Loop-63rd-bound)
# 71     30375            N                    Clark/Lake (O'Hare-bound)
# 70     30374            S                 Clark/Lake (Forest Pk-bound)
# 69     30075            W                      Clark/Lake (Outer Loop)
# 68     30074            E                      Clark/Lake (Inner Loop)
# 207    30199            E                            Polk (Loop-bound)
# 206    30200            W                     Polk (54th/Cermak-bound)
# 179    30090            N      Merchandise Mart (Kimball-Linden-bound)
# 180    30091            S                Merchandise Mart (Loop-bound)
# 217    30008            S                    Quincy/Wells (Outer Loop)
# 216    30007            N                    Quincy/Wells (Inner Loop)
# 250    30141            N                Washington/Wells (Inner Loop)
# 251    30142            S                Washington/Wells (Outer Loop)
# 165    30031            W               LaSalle/Van Buren (Inner Loop)
# 166    30030            E               LaSalle/Van Buren (Outer Loop)
#
#                   STATION_NAME  \
# 175             Madison/Wabash
# 176             Madison/Wabash
# 57            Cermak-Chinatown
# 58            Cermak-Chinatown
# 22                     Addison
# 23                     Addison
# 109                      Grand
# 108                      Grand
# 296                     O'Hare
# 227                     O'Hare
# 162                    Laramie
# 161                    Laramie
# 197             North/Clybourn
# 196             North/Clybourn
# 258                  Roosevelt
# 228                  Roosevelt
# 295                  Roosevelt
# 259                  Roosevelt
# 41                     Belmont
# 43                     Belmont
# 44                     Belmont
# 42                     Belmont
# 269             Clark/Division
# 67              Clark/Division
# 90                    Dempster
# 89                    Dempster
# 286                    Chicago
# 285                    Chicago
# 121                   Harrison
# 120                   Harrison
# ..                         ...
# 73                     Clinton
# 72                     Clinton
# 200                   Oak Park
# 201                   Oak Park
# 223                  Ridgeland
# 224                  Ridgeland
# 284                    Chicago
# 283                    Chicago
# 248                UIC-Halsted
# 247                UIC-Halsted
# 130  Illinois Medical District
# 129  Illinois Medical District
# 191                     Monroe
# 194                     Monroe
# 74                     Clinton
# 75                     Clinton
# 71                  Clark/Lake
# 70                  Clark/Lake
# 69                  Clark/Lake
# 68                  Clark/Lake
# 207                       Polk
# 206                       Polk
# 179           Merchandise Mart
# 180           Merchandise Mart
# 217               Quincy/Wells
# 216               Quincy/Wells
# 250           Washington/Wells
# 251           Washington/Wells
# 165          LaSalle/Van Buren
# 166          LaSalle/Van Buren
#
#                               STATION_DESCRIPTIVE_NAME  MAP_ID    ADA    RED  \
# 175  Madison/Wabash (Brown, Green, Orange, Pink & P...   40640  False  False
# 176  Madison/Wabash (Brown, Green, Orange, Pink & P...   40640  False  False
# 57                         Cermak-Chinatown (Red Line)   41000   True   True
# 58                         Cermak-Chinatown (Red Line)   41000   True   True
# 22                                  Addison (Red Line)   41420   True   True
# 23                                  Addison (Red Line)   41420   True   True
# 109                                   Grand (Red Line)   40330   True   True
# 108                                   Grand (Red Line)   40330   True   True
# 296                                 O'Hare (Blue Line)   40890   True  False
# 227                                 O'Hare (Blue Line)   40890   True  False
# 162                               Laramie (Green Line)   40700   True  False
# 161                               Laramie (Green Line)   40700   True  False
# 197                          North/Clybourn (Red Line)   40650  False   True
# 196                          North/Clybourn (Red Line)   40650  False   True
# 258              Roosevelt (Red, Orange & Green Lines)   41400   True   True
# 228              Roosevelt (Red, Orange & Green Lines)   41400   True  False
# 295              Roosevelt (Red, Orange & Green Lines)   41400   True   True
# 259              Roosevelt (Red, Orange & Green Lines)   41400   True  False
# 41                 Belmont (Red, Brown & Purple Lines)   41320   True   True
# 43                 Belmont (Red, Brown & Purple Lines)   41320   True  False
# 44                 Belmont (Red, Brown & Purple Lines)   41320   True  False
# 42                 Belmont (Red, Brown & Purple Lines)   41320   True   True
# 269                          Clark/Division (Red Line)   40630   True   True
# 67                           Clark/Division (Red Line)   40630  False   True
# 90                              Dempster (Purple Line)   40690  False  False
# 89                              Dempster (Purple Line)   40690  False  False
# 286                                 Chicago (Red Line)   41450   True   True
# 285                                 Chicago (Red Line)   41450   True   True
# 121                                Harrison (Red Line)   41490  False   True
# 120                                Harrison (Red Line)   41490  False   True
# ..                                                 ...     ...    ...    ...
# 73                                 Clinton (Blue Line)   40430  False  False
# 72                                 Clinton (Blue Line)   40430  False  False
# 200                               Oak Park (Blue Line)   40180  False  False
# 201                               Oak Park (Blue Line)   40180  False  False
# 223                             Ridgeland (Green Line)   40610  False  False
# 224                             Ridgeland (Green Line)   40610  False  False
# 284                     Chicago (Brown & Purple Lines)   40710   True  False
# 283                     Chicago (Brown & Purple Lines)   40710   True  False
# 248                            UIC-Halsted (Blue Line)   40350   True  False
# 247                            UIC-Halsted (Blue Line)   40350   True  False
# 130              Illinois Medical District (Blue Line)   40810   True  False
# 129              Illinois Medical District (Blue Line)   40810   True  False
# 191                                 Monroe (Blue Line)   40790  False  False
# 194                                 Monroe (Blue Line)   40790  False  False
# 74                        Clinton (Green & Pink Lines)   41160   True  False
# 75                        Clinton (Green & Pink Lines)   41160   True  False
# 71   Clark/Lake (Blue, Brown, Green, Orange, Purple...   40380   True  False
# 70   Clark/Lake (Blue, Brown, Green, Orange, Purple...   40380   True  False
# 69   Clark/Lake (Blue, Brown, Green, Orange, Purple...   40380   True  False
# 68   Clark/Lake (Blue, Brown, Green, Orange, Purple...   40380   True  False
# 207                                   Polk (Pink Line)   41030   True  False
# 206                                   Polk (Pink Line)   41030   True  False
# 179            Merchandise Mart (Brown & Purple Lines)   40460   True  False
# 180            Merchandise Mart (Brown & Purple Lines)   40460   True  False
# 217  Quincy/Wells (Brown, Orange, Purple & Pink Lines)   40040  False  False
# 216  Quincy/Wells (Brown, Orange, Purple & Pink Lines)   40040  False  False
# 250  Washington/Wells (Brown, Orange, Purple & Pink...   40730   True  False
# 251  Washington/Wells (Brown, Orange, Purple & Pink...   40730   True  False
# 165  LaSalle/Van Buren (Brown, Orange, Purple & Pin...   40160  False  False
# 166  LaSalle/Van Buren (Brown, Orange, Purple & Pin...   40160  False  False
#
#       BLUE      G     ...                         Location Delta_2016_2001  \
# 175  False   True     ...          (41.882023, -87.626098)       -0.999870
# 176  False   True     ...          (41.882023, -87.626098)       -0.999870
# 57   False  False     ...          (41.853206, -87.630968)        0.492547
# 58   False  False     ...          (41.853206, -87.630968)        0.492547
# 22   False  False     ...          (41.947428, -87.653626)        0.424778
# 23   False  False     ...          (41.947428, -87.653626)        0.424778
# 109  False  False     ...          (41.891665, -87.628021)        0.380915
# 108  False  False     ...          (41.891665, -87.628021)        0.380915
# 296   True  False     ...      (41.97766526, -87.90422307)        0.284591
# 227   True  False     ...      (41.97766526, -87.90422307)        0.284591
# 162  False   True     ...          (41.887163, -87.754986)        0.027405
# 161  False   True     ...          (41.887163, -87.754986)        0.027405
# 197  False  False     ...          (41.910655, -87.649177)        0.615387
# 196  False  False     ...          (41.910655, -87.649177)        0.615387
# 258  False  False     ...          (41.867368, -87.627402)        0.769159
# 228  False   True     ...           (41.867405, -87.62659)        0.769159
# 295  False  False     ...          (41.867368, -87.627402)        0.769159
# 259  False   True     ...           (41.867405, -87.62659)        0.769159
# 41   False  False     ...           (41.939751, -87.65338)        0.243661
# 43   False  False     ...           (41.939751, -87.65338)        0.243661
# 44   False  False     ...           (41.939751, -87.65338)        0.243661
# 42   False  False     ...           (41.939751, -87.65338)        0.243661
# 269  False  False     ...           (41.90392, -87.631412)        0.127749
# 67   False  False     ...           (41.90392, -87.631412)        0.127749
# 90   False  False     ...          (42.041655, -87.681602)        0.193274
# 89   False  False     ...          (42.041655, -87.681602)        0.193274
# 286  False  False     ...          (41.896671, -87.628176)        0.151075
# 285  False  False     ...          (41.896671, -87.628176)        0.151075
# 121  False  False     ...          (41.874039, -87.627479)        0.798809
# 120  False  False     ...          (41.874039, -87.627479)        0.798809
# ..     ...    ...     ...                              ...             ...
# 73    True  False     ...          (41.875539, -87.640984)        0.600959
# 72    True  False     ...          (41.875539, -87.640984)        0.600959
# 200   True  False     ...          (41.872108, -87.791602)        0.247880
# 201   True  False     ...          (41.872108, -87.791602)        0.247880
# 223  False   True     ...          (41.887159, -87.783661)       -0.071954
# 224  False   True     ...          (41.887159, -87.783661)       -0.071954
# 269        -0.003950             0.010341  -25.066501
# 67         -0.003950             0.010341  -25.066501
# 90         -0.042141            -0.027850  -27.579248
# 89         -0.042141            -0.027850  -27.579248
# 286        -0.054203            -0.039912  -27.741935
# 285        -0.054203            -0.039912  -27.741935
# 121        -0.008798             0.005494  -29.148093
# 120        -0.008798             0.005494  -29.148093
# ..               ...                  ...         ...
# 73          0.143158             0.157450  -63.026372
# 72          0.143158             0.157450  -63.026372
# 200        -0.052263            -0.037971  -65.559819
# 201        -0.052263            -0.037971  -65.559819
# 223        -0.091397            -0.077105  -69.595739
# 224        -0.091397            -0.077105  -69.595739
# 284        -0.032820            -0.018528  -70.023467
# 283        -0.032820            -0.018528  -70.023467
# 248        -0.018832            -0.004540  -70.372146
# 247        -0.018832            -0.004540  -70.372146
# 130        -0.126388            -0.112096  -71.114185
# 129        -0.126388            -0.112096  -71.114185
# 191         0.131119             0.145410  -71.134347
# 194         0.131119             0.145410  -71.134347
# 74         -0.132753            -0.118461  -71.758838
# 75         -0.132753            -0.118461  -71.758838
# 71          0.029898             0.044190  -71.858370
# 70          0.029898             0.044190  -71.858370
# 69          0.029898             0.044190  -71.858370
# 68          0.029898             0.044190  -71.858370
# 207        -0.065425            -0.051133  -77.566297
# 206        -0.065425            -0.051133  -77.566297
# 179         0.138317             0.152608  -79.364233
# 180         0.138317             0.152608  -79.364233
# 217        -0.078463            -0.064171  -80.119780
# 216        -0.078463            -0.064171  -80.119780
# 250         0.123630             0.137922  -80.665252
# 251         0.123630             0.137922  -80.665252
# 165        -0.124159            -0.109867  -82.856619
# 166        -0.124159            -0.109867  -82.856619
#
# [300 rows x 26 columns]

# %%
(weekend.sum()-weekday.sum())/weekday.sum()
# Out:
# -0.47128860688167817

# %%
stops = stops.groupby('MAP_ID').first()

# %%
stops[stops['RED']==True]['Ridership_2016'].sum()
# Out:
# 66729968

# %%
stops.columns
# Out:
# Index(['STOP_ID', 'STOP_NAME', 'STATION_NAME', 'ADA', 'RED', 'BLUE', 'G',
#        'BRN', 'P', 'Pexp', 'Y', 'Pnk', 'O', 'Location', 'Delta_2016_2001',
#        'Ridership_2016', 'latitude', 'longitude', 'size',
#        'Delta_Rel_2016_2001', 'weekend_use'],
#       dtype='object')

# %%
lines = ['RED', 'BLUE', 'G','BRN', 'P','Y', 'Pnk', 'O']
stops['lines'] = stops[lines].sum(axis=1)

# %%
for line in lines:
    total = stops[stops['lines']<2][stops[line]==True]['Ridership_2016'].sum()
    print("{}: {:.1f} M".format(line,total/1e6))
# Out:
# RED: 66.7 M
# BLUE: 42.8 M
# G: 9.0 M
# BRN: 18.0 M
# P: 3.1 M
# Y: 0.8 M
# Pnk: 4.9 M
# O: 8.4 M
# /home/ubuntu/anaconda2/envs/py3/lib/python3.5/site-packages/ipykernel/__main__.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   from ipykernel import kernelapp as app

# %%
stops['Delta_2016_2011'].mean()
# Out:
# -0.034277518144254907

# %%
(rides_2016.sum()-rides_2011.sum())/rides_2011.sum()
# Out:
# -0.014291627858000226
